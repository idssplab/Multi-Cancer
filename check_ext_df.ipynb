# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
df = pd.read_csv('format_ext_data.csv')
df.head()
# Out:
#    age_at_diagnosis  year_of_diagnosis  year_of_birth  overall_survival  \
# 0         -1.965718                0.0       1.965718              38.0
# 1         -0.018517                0.0       0.018517              12.0
# 2         -1.965718                0.0       1.965718              42.0
# 3         -0.018517                0.0       0.018517              13.0
# 4         -1.208473                0.0       1.208473              33.0
#
#    vital_status  disease_specific_survival  gender_female  gender_male  \
# 0             1                       38.0            0.0          1.0
# 1             1                       12.0            1.0          0.0
# 2             1                       42.0            0.0          1.0
# 3             1                       13.0            0.0          1.0
# 4             1                       33.0            1.0          0.0
#
#    race_not reported  race_white  ...   COL11A1     CSMD1     SYNE1       EYS  \
# ...
