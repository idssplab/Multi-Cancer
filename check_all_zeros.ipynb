# %%
import pandas as pd

# Load the clinical data from the uploaded CSV file
file_path = 'clin_data.csv'
clinical_data = pd.read_csv(file_path)

# Identify columns that are all zeroes
columns_all_zeroes = [col for col in clinical_data.columns if clinical_data[col].eq(0).all()]

columns_all_zeroes
# Out:
# ['year_of_diagnosis',
#  'year_of_birth',
#  'gender_female',
#  'race_asian',
#  'race_white',
#  'race_black or african american',
#  'race_not reported',
#  'race_american indian or alaska native',
#  'ethnicity_hispanic or latino',
#  'race_native hawaiian or other pacific islander']
